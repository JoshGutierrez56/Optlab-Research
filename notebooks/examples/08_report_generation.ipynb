# %% [markdown]
# # Week 8 — Report Generation
# Generate a professional HTML report from a backtest result.
# The report is self-contained (all charts embedded as base64) and can be emailed or printed.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../..'))
import matplotlib
matplotlib.use('Agg')
from optlab_research.reporting import BacktestReport
from optlab_research.reporting.report import ReportConfig
print("Reporting module loaded")

# %% [markdown]
# ## Load a saved backtest result

# %%
import pickle, os
# Load momentum result if it exists, otherwise note it needs to be run first
result_path = "../../outputs/01_momentum_replication"
if os.path.exists(result_path):
 # BacktestResult.load() — adjust path as needed
 print(f"Found result at: {result_path}")
 print("Load with: result = BacktestResult.load(result_path)")
else:
 print("Run 01_momentum_replication.ipynb first to generate a result.")
 print("Then load it here and run rpt.save()")

# %% [markdown]
# ## Generate the report

# %%
# Once result is loaded:
# config = ReportConfig(
# title="Momentum Factor — Jegadeesh-Titman (1993)",
# subtitle="Russell 3000 Universe | 2019–2023 | Equal-Weight Quintile Long-Short",
# institution="Northeastern University — 360 Huntington Fund",
# )
# rpt = BacktestReport(result, config=config)
# rpt.save("outputs/momentum_report.html")
# print("Report saved. Open momentum_report.html in a browser.")
print("Uncomment above after loading a result.")

# %% [markdown]
# ## Acceptance Criterion
# `BacktestReport(result).save("outputs/report.html")` produces a self-contained HTML file
# with cumulative returns chart, drawdown chart, monthly returns heatmap,
# executive summary table, and methodology notes.
# The file can be opened in any browser and printed to PDF.
